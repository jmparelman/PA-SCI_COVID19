# %% [markdown]
# # Process PA DOC testing data from emails
#
# * We received the daily PA DOC testing data from a bunch of forwarded emails.
#
#
# * Some of them contained pasted tables (presumably from an Excel file) while others were an Excel attachment.
#
#
# * __ISSUES__
#   1. the format and column names and some data changes over the period from April 6 through July
#   2. The email tables were difficult to scrape because of HTML format issues etc.
#
#
# * __PROCEDURE__
#   1. we compiled four different tyoes of excel files for the four different formats we identified.
#   2. the email tables where pasted into a sheet/tab of a spreadsheet with the date as the sheet name
#   3. This notebook processes these four different formats and does the appropriate column selection and renaming
#   4. The appropriate report date is added for each row extracted and a single data frame results
#
# ----------
#
# #### HISTORY
#
# * 11/20/20 mbod - add in the inmate testing purpose columns
# * 7/21/20 mbod - parse the four different spreadsheets into a single dataframe

# %% [markdown]
# ### Setup

# %%
import pandas as pd
import os
import re

# %%
DATA_DIR = '../data/PA_DOC_testing_data/'

# %%
files_to_process=[f for f in os.listdir(DATA_DIR) if f.endswith('.xlsx')]

# %%
files_to_process.sort()
files_to_process
# Out:
# ['April6-June1.xlsx',
#  'June2-8.xlsx',
#  'PA-DOC-COVID-19-Testing_10-1.xlsx',
#  'PA-DOC-COVID-19-Testing_10-10.xlsx',
#  'PA-DOC-COVID-19-Testing_10-11.xlsx',
#  'PA-DOC-COVID-19-Testing_10-12.xlsx',
#  'PA-DOC-COVID-19-Testing_10-13.xlsx',
#  'PA-DOC-COVID-19-Testing_10-14.xlsx',
#  'PA-DOC-COVID-19-Testing_10-15.xlsx',
#  'PA-DOC-COVID-19-Testing_10-16.xlsx',
#  'PA-DOC-COVID-19-Testing_10-17.xlsx',
#  'PA-DOC-COVID-19-Testing_10-18.xlsx',
#  'PA-DOC-COVID-19-Testing_10-19.xlsx',
#  'PA-DOC-COVID-19-Testing_10-2.xlsx',
#  'PA-DOC-COVID-19-Testing_10-20.xlsx',
#  'PA-DOC-COVID-19-Testing_10-21.xlsx',
#  'PA-DOC-COVID-19-Testing_10-22.xlsx',
#  'PA-DOC-COVID-19-Testing_10-23.xlsx',
#  'PA-DOC-COVID-19-Testing_10-24.xlsx',
#  'PA-DOC-COVID-19-Testing_10-25.xlsx',
#  'PA-DOC-COVID-19-Testing_10-26.xlsx',
#  'PA-DOC-COVID-19-Testing_10-31.xlsx',
#  'PA-DOC-COVID-19-Testing_10-5.xlsx',
#  'PA-DOC-COVID-19-Testing_10-6.xlsx',
#  'PA-DOC-COVID-19-Testing_10-7.xlsx',
#  'PA-DOC-COVID-19-Testing_10-8.xlsx',
#  'PA-DOC-COVID-19-Testing_10-9.xlsx',
#  'PA-DOC-COVID-19-Testing_11-10.xlsx',
#  'PA-DOC-COVID-19-Testing_11-13.xlsx',
#  'PA-DOC-COVID-19-Testing_11-15.xlsx',
#  'PA-DOC-COVID-19-Testing_11-16.xlsx',
#  'PA-DOC-COVID-19-Testing_11-17.xlsx',
#  'PA-DOC-COVID-19-Testing_11-18.xlsx',
#  'PA-DOC-COVID-19-Testing_11-19.xlsx',
#  'PA-DOC-COVID-19-Testing_11-20.xlsx',
#  'PA-DOC-COVID-19-Testing_11-21.xlsx',
#  'PA-DOC-COVID-19-Testing_11-23.xlsx',
#  'PA-DOC-COVID-19-Testing_11-5.xlsx',
#  'PA-DOC-COVID-19-Testing_11-9.xlsx',
#  'PA-DOC-COVID-19-Testing_7-17.xlsx',
#  'PA-DOC-COVID-19-Testing_7-18.xlsx',
#  'PA-DOC-COVID-19-Testing_7-19.xlsx',
#  'PA-DOC-COVID-19-Testing_7-23.xlsx',
#  'PA-DOC-COVID-19-Testing_7-24.xlsx',
#  'PA-DOC-COVID-19-Testing_7-30.xlsx',
#  'PA-DOC-COVID-19-Testing_8-12.xlsx',
#  'PA-DOC-COVID-19-Testing_8-13.xlsx',
#  'PA-DOC-COVID-19-Testing_8-27.xlsx',
#  'PA-DOC-COVID-19-Testing_8-4.xlsx',
#  'PA-DOC-COVID-19-Testing_8-9.xlsx',
#  'PA-DOC-COVID-19-Testing_9-25.xlsx',
#  'Staff_Turn_Away_Report_6-10.xlsx',
#  'Staff_Turn_Away_Report_6-11.xlsx',
#  'Staff_Turn_Away_Report_6-12.xlsx',
#  'Staff_Turn_Away_Report_6-15.xlsx',
#  'Staff_Turn_Away_Report_6-16.xlsx',
#  'Staff_Turn_Away_Report_6-18.xlsx',
#  'Staff_Turn_Away_Report_6-22.xlsx',
#  'Staff_Turn_Away_Report_6-23.xlsx',
#  'Staff_Turn_Away_Report_6-24.xlsx',
#  'Staff_Turn_Away_Report_6-25.xlsx',
#  'Staff_Turn_Away_Report_6-26.xlsx',
#  'Staff_Turn_Away_Report_6-29.xlsx',
#  'Staff_Turn_Away_Report_6-30.xlsx',
#  'Staff_Turn_Away_Report_7-1.xlsx',
#  'Staff_Turn_Away_Report_7-10.xlsx',
#  'Staff_Turn_Away_Report_7-13.xlsx',
#  'Staff_Turn_Away_Report_7-14.xlsx',
#  'Staff_Turn_Away_Report_7-15.xlsx',
#  'Staff_Turn_Away_Report_7-2.xlsx',
#  'Staff_Turn_Away_Report_7-6.xlsx',
#  'Staff_Turn_Away_Report_7-7.xlsx',
#  'Staff_Turn_Away_Report_7-8.xlsx',
#  'Staff_Turn_Away_Report_7-9.xlsx',
#  'Staff_turn_around__ALTFORMAT_4_1.xlsx']

# %% [markdown]
# ### 1. Processing `Staff_Turn_Away` reports for 6-10 through 7-15
#
#
# ![](img/staff_turn_around_excel1.png)

# %% [markdown]
# #### Columns and rows to extract
#
# * First 25 rows after headers and `Central Office` have the SCI institutions of interest
#     * Down to `Waymart`
#     * Ignore `Training Academy` and `Parole` and the other facilities/locations in blue
#
#
# * Keep these columns:
#     1. `SCI/Institution` map to `SCI`
#     2. `Staff Positive` map to 'staff_positive`
#     3. `Staff Negative` map to 'staff_negative`
#     4. `Staff Pending` map to 'staff_pending`
#     5. `Staff Death With(+) Test` map to `staff_death`
#     6. `Staff Recovered` map to `incarcerated_person_recovered`
#     7. `Inmate Positive` map to `incarcerated_person_positive`
#     8. `Inmate Negative` map to `incarcerated_person_negative`
#     9. `Inmate Pending` map to `incarcerated_person_pending`
#     10. `Inmate Death With(+) Test` map to `incarcerated_person_death`
#     11. `Inmate Recovered` map to `incarcerated_person_recovered`
#
#
# * Add date column

# %%
column_mapping = {
 'SCI/Institution': 'SCI',
 'Staff Positive': 'staff_positive',
 'Staff Negative': 'staff_negative',
 'Staff Pending': 'staff_pending',
 'Staff Death With(+) Test ': 'staff_death',
 'Staff Recovered': 'staff_recovered',
 'Inmate Positive': 'incarcerated_person_positive',
 'Inmate Negative': 'incarcerated_person_negative',
 'Inmate Pending': 'incarcerated_person_pending',
 'Inmate Death With(+) Test ': 'incarcerated_person_death',
 'Inmate Recovered': 'incarcerated_person_recovered',
 # testing purpose columns
 'Transfer': 'test_transfer', 
 'Transfer (+)': 'test_transfer_positive', 
 'Release': 'test_release',
 'Release (+)': 'test_release_positive', 
 'Hospital': 'test_hospital', 
 'Hospital (+)': 'test_hospital_positive', 
 'Surveilance': 'test_surveilance',
 'Surveilance (+)': 'test_surveilance_positive', 
 'Symptomatic': 'test_symptomatic', 
 'Symptomatic (+)': 'test_symptomatic_positive', 
 'Miscellaneous': 'test_miscellaneous'
}

# %%
test_df = pd.read_excel(os.path.join(DATA_DIR, 'Staff_Turn_Away_Report_6-10.xlsx'))

# %%
select_columns=test_df.columns[:]

# %%
test_df2=test_df.iloc[1:26][select_columns]
test_df2.rename(columns=column_mapping, inplace=True)
test_df2['date']='2020-06-10'

# %%
test_df2.head()
# Out:
#                  SCI  staff_positive  staff_negative  staff_pending  \
# 1             Albion             NaN             7.0            4.0
# 2    Benner Township             NaN            11.0            1.0
# 3  Cambridge Springs             NaN             7.0            2.0
# 4          Camp Hill             4.0             8.0           20.0
# 5            Chester            16.0            14.0           17.0
#
#    staff_death  staff_recovered  incarcerated_person_positive  \
# 1          NaN              NaN                           NaN
# 2          NaN              NaN                           1.0
# 3          NaN              NaN                           NaN
# 4          NaN              3.0                           1.0
# 5          NaN             13.0                           5.0
#
#    incarcerated_person_negative  incarcerated_person_pending  \
# 1                          62.0                          NaN
# 2                          82.0                          NaN
# 3                         126.0                          NaN
# 4                         985.0                          2.0
# 5                         231.0                          NaN
#
#    incarcerated_person_death  ...  test_release  test_release_positive  \
# 1                        NaN  ...          48.0                    NaN
# 2                        NaN  ...          39.0                    1.0
# 3                        NaN  ...         116.0                    NaN
# 4                        NaN  ...         104.0                    NaN
# 5                        NaN  ...          72.0                    NaN
#
#    test_hospital  test_hospital_positive  test_surveilance  \
# 1            3.0                     NaN               NaN
# 2            3.0                     NaN              36.0
# 3            NaN                     NaN               NaN
# 4            6.0                     NaN               NaN
# 5            2.0                     NaN             147.0
#
#    test_surveilance_positive  test_symptomatic  test_symptomatic_positive  \
# 1                        NaN               1.0                        NaN
# 2                        NaN               5.0                        NaN
# 3                        NaN               2.0                        NaN
# 4                        NaN               7.0                        1.0
# 5                        3.0               3.0                        2.0
#
#    test_miscellaneous        date
# 1                 NaN  2020-06-10
# 2                 NaN  2020-06-10
# 3                 NaN  2020-06-10
# 4                 NaN  2020-06-10
# 5                 NaN  2020-06-10
#
# [5 rows x 23 columns]

# %%
def process_STA_report(fname):
    
    month, day = re.match('Staff_Turn_Away_Report_(\d+)-(\d+)\.xlsx', fname).groups()
    
    date = "2020-{:0>2}-{:0>2}".format(month,day)
    
    df = pd.read_excel(os.path.join(DATA_DIR, fname))
    
    df2=df.iloc[1:26][select_columns]
    df2.rename(columns=column_mapping, inplace=True)
    df2['date']=date
    
    return df2

# %%
data_type1 = []
for dsheet in files_to_process:
    if dsheet.startswith('Staff_Turn_Away_Report_'):
        print('Processing', dsheet)
        data_type1.append(process_STA_report(dsheet))
# Out:
# Processing Staff_Turn_Away_Report_6-10.xlsx
# Processing Staff_Turn_Away_Report_6-11.xlsx
# Processing Staff_Turn_Away_Report_6-12.xlsx
# Processing Staff_Turn_Away_Report_6-15.xlsx
# Processing Staff_Turn_Away_Report_6-16.xlsx
# Processing Staff_Turn_Away_Report_6-18.xlsx
# Processing Staff_Turn_Away_Report_6-22.xlsx
# Processing Staff_Turn_Away_Report_6-23.xlsx
# Processing Staff_Turn_Away_Report_6-24.xlsx
# Processing Staff_Turn_Away_Report_6-25.xlsx
# Processing Staff_Turn_Away_Report_6-26.xlsx
# Processing Staff_Turn_Away_Report_6-29.xlsx
# Processing Staff_Turn_Away_Report_6-30.xlsx
# Processing Staff_Turn_Away_Report_7-1.xlsx
# Processing Staff_Turn_Away_Report_7-10.xlsx
# Processing Staff_Turn_Away_Report_7-13.xlsx
# Processing Staff_Turn_Away_Report_7-14.xlsx
# Processing Staff_Turn_Away_Report_7-15.xlsx
# Processing Staff_Turn_Away_Report_7-2.xlsx
# Processing Staff_Turn_Away_Report_7-6.xlsx
# Processing Staff_Turn_Away_Report_7-7.xlsx
# Processing Staff_Turn_Away_Report_7-8.xlsx
# Processing Staff_Turn_Away_Report_7-9.xlsx

# %% [markdown]
# ### 2. PA DOC Covid Testing data sheet
#
# ![](img/covid_testing_excel.png)

# %% [markdown]
# #### Columns and rows to extract
#
# * Skip first row on load to get column headings
#
# * First 25 rows after headers and `Central Office` have the SCI institutions of interest
#     * Down to `Waymart`
#     * Ignore `Training Academy` and `Parole` and the other facilities/locations in blue
#
#
# * Keep these columns:
#     1. `LOCATION` map to `SCI`
#     2. `Positive` (col 2) map to 'staff_positive`
#     3. `Negative` (col 3) map to 'staff_negative`
#     4. `Pending` (col 4) map to 'staff_pending`
#     5. `Death` map to `staff_death`
#     6. `Recovered` map to `incarcerated_person_recovered`
#     7. `Positive` (col 7) map to 'incarcerated_person_positive`
#     8. `Negative` map to 'incarcerated_person_negative`
#     9. `Pending` map to 'incarcerated_person_pending`
#     10. `Death` map to `incarcerated_person_death`
#     11. `Recovered` map to `incarcerated_person_recovered`
#
#
# * Add date column

# %%
column_mapping2 = {
 'Unnamed: 0': 'SCI',
 'Positive': 'staff_positive',
 'Negative': 'staff_negative',
 'Pending': 'staff_pending',
 'Death*': 'staff_death',
 'Recovered': 'staff_recovered',
 'Positive.1': 'incarcerated_person_positive',
 'Negative.1': 'incarcerated_person_negative',
 'Pending.1': 'incarcerated_person_pending',
 'Death*.1': 'incarcerated_person_death',
 'Recovered.1': 'incarcerated_person_recovered',
    
  # test purpose columns added 
  # 'Transfer', 'Transfer (+)', 'Release', 'Release (+)', 'Hospital',
  # 'Hospital (+)', 'Surveilance', 'Surveilance (+)', 'Symptomatic',
  # 'Symptomatic (+)'

 'Transfer': 'test_transfer', 
 'Transfer (+)': 'test_transfer_positive', 
 'Release': 'test_release',
 'Release (+)': 'test_release_positive', 
 'Hospital': 'test_hospital', 
 'Hospital (+)': 'test_hospital_positive', 
 'Surveilance': 'test_surveilance',
 'Surveilance (+)': 'test_surveilance_positive', 
 'Symptomatic': 'test_symptomatic', 
 'Symptomatic (+)': 'test_symptomatic_positive' 
    
}

# %%
def process_testing_report(fname):
    
    month, day = re.match('PA-DOC-COVID-19-Testing_(\d+)-(\d+)\.xlsx', fname).groups()
    
    date = "2020-{:0>2}-{:0>2}".format(month,day)
    
    df = pd.read_excel(os.path.join(DATA_DIR, fname), skiprows=1)
    df.rename(columns=column_mapping2, inplace=True)
    df2=df.iloc[1:26][column_mapping2.values()]
    df2['date']=date
    
    return df2

# %%
process_testing_report('PA-DOC-COVID-19-Testing_7-19.xlsx')
# Out:
#                   SCI  staff_positive  staff_negative  staff_pending  \
# 1              Albion             NaN            11.0            4.0
# 2     Benner Township             NaN            17.0            6.0
# 3   Cambridge Springs             NaN            10.0            1.0
# 4           Camp Hill             4.0             8.0           29.0
# 5             Chester            16.0            14.0           18.0
# 6       Coal Township             2.0            17.0            1.0
# 7              Dallas             3.0            11.0            3.0
# 8             Fayette             9.0            40.0            4.0
# 9              Forest             NaN             9.0            3.0
# 10         Frackville             NaN            20.0           11.0
# 11             Greene             6.0            60.0           18.0
# 12          Houtzdale             NaN             8.0            6.0
# 13         Huntingdon            54.0           104.0           12.0
# 14   Laurel Highlands             2.0             7.0            6.0
# 15            Mahanoy             NaN            13.0            9.0
# 16             Mercer             NaN             8.0            1.0
# 17              Muncy             1.0            19.0            6.0
# 18            Phoenix            84.0           108.0            8.0
# 19         Pine Grove             NaN             2.0            NaN
# 20        Quehanna BC             NaN             1.0            1.0
# 21            Retreat             4.0            10.0            NaN
# 22           Rockview             3.0            12.0            5.0
# 23         Smithfield             3.0            26.0           13.0
# 24           Somerset             NaN             6.0            4.0
# 25            Waymart             3.0            45.0            2.0
#
#     staff_death  staff_recovered  incarcerated_person_positive  \
# 1           NaN              NaN                           3.0
# 2           NaN              NaN                           1.0
# 3           NaN              NaN                           2.0
# 4           NaN              3.0                           1.0
# 5           NaN             14.0                           5.0
# 6           NaN              2.0                           4.0
# 7           NaN              NaN                           NaN
# 8           NaN              5.0                           1.0
# 9           NaN              NaN                           NaN
# 10          NaN              NaN                           NaN
# 11          NaN              1.0                           2.0
# 12          NaN              NaN                           NaN
# 13          NaN             48.0                         183.0
# 14          NaN              1.0                           NaN
# 15          NaN              NaN                           NaN
# 16          NaN              NaN                           NaN
# 17          NaN              1.0                           2.0
# 18          1.0             69.0                          49.0
# 19          NaN              NaN                           NaN
# 20          NaN              NaN                           NaN
# 21          NaN              4.0                          13.0
# 22          NaN              NaN                           NaN
# 23          NaN              3.0                           NaN
# 24          NaN              NaN                           NaN
# 25          NaN              3.0                           NaN
#
#     incarcerated_person_negative  incarcerated_person_pending  \
# 1                          134.0                          NaN
# 2                          155.0                          NaN
# 3                          197.0                          NaN
# 4                         1779.0                          1.0
# 5                          299.0                          NaN
# 6                          240.0                          NaN
# 7                          202.0                          NaN
# 8                          184.0                          NaN
# 9                          106.0                          NaN
# 10                         112.0                          NaN
# 11                         146.0                          NaN
# 12                         151.0                          NaN
# 13                         177.0                          NaN
# 14                         175.0                          2.0
# 15                         133.0                          NaN
# 16                         137.0                          NaN
# 17                         308.0                          NaN
# 18                         333.0                          NaN
# 19                          88.0                          NaN
# 20                         106.0                          NaN
# 21                        1048.0                          NaN
# 22                         119.0                          NaN
# 23                          87.0                          NaN
# 24                         126.0                          NaN
# 25                         196.0                          1.0
#
#     incarcerated_person_death  ...  test_transfer_positive  test_release  \
# 1                         NaN  ...                     1.0         112.0
# 2                         1.0  ...                     NaN          79.0
# 3                         NaN  ...                     NaN         177.0
# 4                         NaN  ...                     NaN         216.0
# 5                         NaN  ...                     NaN         140.0
# 6                         NaN  ...                     NaN         101.0
# 7                         NaN  ...                     NaN          92.0
# 8                         NaN  ...                     NaN         130.0
# 9                         NaN  ...                     NaN          66.0
# 10                        NaN  ...                     NaN          96.0
# 11                        NaN  ...                     NaN          65.0
# 12                        NaN  ...                     NaN          93.0
# 13                        5.0  ...                     NaN          31.0
# 14                        NaN  ...                     NaN         140.0
# 15                        NaN  ...                     NaN          98.0
# 16                        NaN  ...                     NaN         107.0
# 17                        NaN  ...                     1.0         112.0
# 18                        4.0  ...                     3.0         138.0
# 19                        NaN  ...                     NaN          78.0
# 20                        NaN  ...                     NaN         102.0
# 21                        NaN  ...                     7.0          25.0
# 22                        NaN  ...                     NaN          79.0
# 23                        NaN  ...                     NaN          56.0
# 24                        NaN  ...                     NaN          99.0
# 25                        NaN  ...                     NaN         160.0
#
#     test_release_positive  test_hospital  test_hospital_positive  \
# 1                     2.0            9.0                     NaN
# 2                     1.0           10.0                     NaN
# 3                     2.0            1.0                     NaN
# 4                     NaN            8.0                     NaN
# 5                     NaN            4.0                     NaN
# 6                     NaN            8.0                     NaN
# 7                     NaN            7.0                     NaN
# 8                     NaN            6.0                     1.0
# 9                     NaN            3.0                     NaN
# 10                    NaN            2.0                     NaN
# 11                    1.0            4.0                     NaN
# 12                    NaN           13.0                     NaN
# 13                    5.0           15.0                     8.0
# 14                    NaN           12.0                     NaN
# 15                    NaN           19.0                     NaN
# 16                    NaN            9.0                     NaN
# 17                    NaN           26.0                     NaN
# 18                    5.0           16.0                     5.0
# 19                    NaN            2.0                     NaN
# 20                    NaN            NaN                     NaN
# 21                    1.0            1.0                     NaN
# 22                    NaN           10.0                     NaN
# 23                    NaN            6.0                     NaN
# 24                    NaN            4.0                     NaN
# 25                    NaN            3.0                     NaN
#
#     test_surveilance  test_surveilance_positive  test_symptomatic  \
# 1                1.0                        NaN               3.0
# 2               37.0                        NaN               6.0
# 3                6.0                        NaN               2.0
# 4                NaN                        NaN               8.0
# 5              147.0                        3.0               6.0
# 6               74.0                        4.0               5.0
# 7                1.0                        NaN               6.0
# 8                NaN                        NaN               4.0
# 9                NaN                        NaN               4.0
# 10               NaN                        NaN               2.0
# 11              46.0                        1.0               5.0
# 12               NaN                        NaN               4.0
# 13             109.0                       43.0             182.0
# 14               NaN                        NaN              20.0
# 15               NaN                        NaN               4.0
# 16               NaN                        NaN               6.0
# 17               8.0                        1.0              24.0
# 18              96.0                        4.0              50.0
# 19               1.0                        NaN               1.0
# 20               NaN                        NaN               1.0
# 21              54.0                        3.0               3.0
# 22               NaN                        NaN               8.0
# 23               2.0                        NaN               2.0
# 24               NaN                        NaN               4.0
# 25               NaN                        NaN               5.0
#
#     test_symptomatic_positive        date
# 1                         NaN  2020-07-19
# 2                         NaN  2020-07-19
# 3                         NaN  2020-07-19
# 4                         1.0  2020-07-19
# 5                         2.0  2020-07-19
# 6                         NaN  2020-07-19
# 7                         NaN  2020-07-19
# 8                         NaN  2020-07-19
# 9                         NaN  2020-07-19
# 10                        NaN  2020-07-19
# 11                        NaN  2020-07-19
# 12                        NaN  2020-07-19
# 13                      127.0  2020-07-19
# 14                        NaN  2020-07-19
# 15                        NaN  2020-07-19
# 16                        NaN  2020-07-19
# 17                        NaN  2020-07-19
# 18                       32.0  2020-07-19
# 19                        NaN  2020-07-19
# 20                        NaN  2020-07-19
# 21                        NaN  2020-07-19
# 22                        NaN  2020-07-19
# 23                        NaN  2020-07-19
# 24                        NaN  2020-07-19
# 25                        NaN  2020-07-19
#
# [25 rows x 22 columns]

# %%
tdf = pd.read_excel('../data/PA_DOC_testing_data/PA-DOC-COVID-19-Testing_7-19.xlsx', skiprows=1)

# %%
tdf.rename(columns=column_mapping2)[1:26]
# Out:
#                   SCI  staff_positive  staff_negative  staff_pending  \
# 1              Albion             NaN            11.0            4.0
# 2     Benner Township             NaN            17.0            6.0
# 3   Cambridge Springs             NaN            10.0            1.0
# 4           Camp Hill             4.0             8.0           29.0
# 5             Chester            16.0            14.0           18.0
# 6       Coal Township             2.0            17.0            1.0
# 7              Dallas             3.0            11.0            3.0
# 8             Fayette             9.0            40.0            4.0
# 9              Forest             NaN             9.0            3.0
# 10         Frackville             NaN            20.0           11.0
# 11             Greene             6.0            60.0           18.0
# 12          Houtzdale             NaN             8.0            6.0
# 13         Huntingdon            54.0           104.0           12.0
# 14   Laurel Highlands             2.0             7.0            6.0
# 15            Mahanoy             NaN            13.0            9.0
# 16             Mercer             NaN             8.0            1.0
# 17              Muncy             1.0            19.0            6.0
# 18            Phoenix            84.0           108.0            8.0
# 19         Pine Grove             NaN             2.0            NaN
# 20        Quehanna BC             NaN             1.0            1.0
# 21            Retreat             4.0            10.0            NaN
# 22           Rockview             3.0            12.0            5.0
# 23         Smithfield             3.0            26.0           13.0
# 24           Somerset             NaN             6.0            4.0
# 25            Waymart             3.0            45.0            2.0
#
#     staff_death  staff_recovered  incarcerated_person_positive  \
# 1           NaN              NaN                           3.0
# 2           NaN              NaN                           1.0
# 3           NaN              NaN                           2.0
# 4           NaN              3.0                           1.0
# 5           NaN             14.0                           5.0
# 6           NaN              2.0                           4.0
# 7           NaN              NaN                           NaN
# 8           NaN              5.0                           1.0
# 9           NaN              NaN                           NaN
# 10          NaN              NaN                           NaN
# 11          NaN              1.0                           2.0
# 12          NaN              NaN                           NaN
# 13          NaN             48.0                         183.0
# 14          NaN              1.0                           NaN
# 15          NaN              NaN                           NaN
# 16          NaN              NaN                           NaN
# 17          NaN              1.0                           2.0
# 18          1.0             69.0                          49.0
# 19          NaN              NaN                           NaN
# 20          NaN              NaN                           NaN
# 21          NaN              4.0                          13.0
# 22          NaN              NaN                           NaN
# 23          NaN              3.0                           NaN
# 24          NaN              NaN                           NaN
# 25          NaN              3.0                           NaN
#
#     incarcerated_person_negative  incarcerated_person_pending  \
# 1                          134.0                          NaN
# 2                          155.0                          NaN
# 3                          197.0                          NaN
# 4                         1779.0                          1.0
# 5                          299.0                          NaN
# 6                          240.0                          NaN
# 7                          202.0                          NaN
# 8                          184.0                          NaN
# 9                          106.0                          NaN
# 10                         112.0                          NaN
# 11                         146.0                          NaN
# 12                         151.0                          NaN
# 13                         177.0                          NaN
# 14                         175.0                          2.0
# 15                         133.0                          NaN
# 16                         137.0                          NaN
# 17                         308.0                          NaN
# 18                         333.0                          NaN
# 19                          88.0                          NaN
# 20                         106.0                          NaN
# 21                        1048.0                          NaN
# 22                         119.0                          NaN
# 23                          87.0                          NaN
# 24                         126.0                          NaN
# 25                         196.0                          1.0
#
#     incarcerated_person_death  ...  test_hospital_positive  test_surveilance  \
# 1                         NaN  ...                     NaN               1.0
# 2                         1.0  ...                     NaN              37.0
# 3                         NaN  ...                     NaN               6.0
# 4                         NaN  ...                     NaN               NaN
# 5                         NaN  ...                     NaN             147.0
# 6                         NaN  ...                     NaN              74.0
# 7                         NaN  ...                     NaN               1.0
# 8                         NaN  ...                     1.0               NaN
# 9                         NaN  ...                     NaN               NaN
# 10                        NaN  ...                     NaN               NaN
# 11                        NaN  ...                     NaN              46.0
# 12                        NaN  ...                     NaN               NaN
# 13                        5.0  ...                     8.0             109.0
# 14                        NaN  ...                     NaN               NaN
# 15                        NaN  ...                     NaN               NaN
# 16                        NaN  ...                     NaN               NaN
# 17                        NaN  ...                     NaN               8.0
# 18                        4.0  ...                     5.0              96.0
# 19                        NaN  ...                     NaN               1.0
# 20                        NaN  ...                     NaN               NaN
# 21                        NaN  ...                     NaN              54.0
# 22                        NaN  ...                     NaN               NaN
# 23                        NaN  ...                     NaN               2.0
# 24                        NaN  ...                     NaN               NaN
# 25                        NaN  ...                     NaN               NaN
#
#     test_surveilance_positive  test_symptomatic  test_symptomatic_positive  \
# 1                         NaN               3.0                        NaN
# 2                         NaN               6.0                        NaN
# 3                         NaN               2.0                        NaN
# 4                         NaN               8.0                        1.0
# 5                         3.0               6.0                        2.0
# 6                         4.0               5.0                        NaN
# 7                         NaN               6.0                        NaN
# 8                         NaN               4.0                        NaN
# 9                         NaN               4.0                        NaN
# 10                        NaN               2.0                        NaN
# 11                        1.0               5.0                        NaN
# 12                        NaN               4.0                        NaN
# 13                       43.0             182.0                      127.0
# 14                        NaN              20.0                        NaN
# 15                        NaN               4.0                        NaN
# 16                        NaN               6.0                        NaN
# 17                        1.0              24.0                        NaN
# 18                        4.0              50.0                       32.0
# 19                        NaN               1.0                        NaN
# 20                        NaN               1.0                        NaN
# 21                        3.0               3.0                        NaN
# 22                        NaN               8.0                        NaN
# 23                        NaN               2.0                        NaN
# 24                        NaN               4.0                        NaN
# 25                        NaN               5.0                        NaN
#
#     Unnamed: 21                                        Unnamed: 22  \
# 1           NaN                                                NaN
# 2           NaN  The positive column shows number of positive t...
# 3           NaN                                                NaN
# 4           NaN                                                NaN
# 5           NaN                                                NaN
# 6           NaN                                                NaN
# 7           NaN                                                NaN
# 8           NaN                                                NaN
# 9           NaN                                                NaN
# 10          NaN                                                NaN
# 11          NaN                                                NaN
# 12          NaN  NOTE: The testing purpose figures are not in a...
# 13          NaN                                                NaN
# 14          NaN                                                NaN
# 15          NaN                                                NaN
# 16          NaN                                                NaN
# 17          NaN                                                NaN
# 18          NaN                                                NaN
# 19          NaN                                                NaN
# 20          NaN                                                NaN
# 21          NaN                                                NaN
# 22          NaN                                                NaN
# 23          NaN                                                NaN
# 24          NaN                                                NaN
# 25          NaN                                                NaN
#
#     Unnamed: 23  Unnamed: 24  Unnamed: 25
# 1           NaN          NaN          NaN
# 2           NaN          NaN          NaN
# 3           NaN          NaN          NaN
# 4           NaN          NaN          NaN
# 5           NaN          NaN          NaN
# 6           NaN          NaN          NaN
# 7           NaN          NaN          NaN
# 8           NaN          NaN          NaN
# 9           NaN          NaN          NaN
# 10          NaN          NaN          NaN
# 11          NaN          NaN          NaN
# 12          NaN          NaN          NaN
# 13          NaN          NaN          NaN
# 14          NaN          NaN          NaN
# 15          NaN          NaN          NaN
# 16          NaN          NaN          NaN
# 17          NaN          NaN          NaN
# 18          NaN          NaN          NaN
# 19          NaN          NaN          NaN
# 20          NaN          NaN          NaN
# 21          NaN          NaN          NaN
# 22          NaN          NaN          NaN
# 23          NaN          NaN          NaN
# 24          NaN          NaN          NaN
# 25          NaN          NaN          NaN
#
# [25 rows x 26 columns]

# %%
data_type2 = []
for dsheet in files_to_process:
    if dsheet.startswith('PA-DOC-COVID-19-Testing_'):
        print('Processing', dsheet)
        data_type2.append(process_testing_report(dsheet))
# Out:
# Processing PA-DOC-COVID-19-Testing_10-1.xlsx
# Processing PA-DOC-COVID-19-Testing_10-10.xlsx
# Processing PA-DOC-COVID-19-Testing_10-11.xlsx
# Processing PA-DOC-COVID-19-Testing_10-12.xlsx
# Processing PA-DOC-COVID-19-Testing_10-13.xlsx
# Processing PA-DOC-COVID-19-Testing_10-14.xlsx
# Processing PA-DOC-COVID-19-Testing_10-15.xlsx
# Processing PA-DOC-COVID-19-Testing_10-16.xlsx
# Processing PA-DOC-COVID-19-Testing_10-17.xlsx
# Processing PA-DOC-COVID-19-Testing_10-18.xlsx
# Processing PA-DOC-COVID-19-Testing_10-19.xlsx
# Processing PA-DOC-COVID-19-Testing_10-2.xlsx
# Processing PA-DOC-COVID-19-Testing_10-20.xlsx
# Processing PA-DOC-COVID-19-Testing_10-21.xlsx
# Processing PA-DOC-COVID-19-Testing_10-22.xlsx
# Processing PA-DOC-COVID-19-Testing_10-23.xlsx
# Processing PA-DOC-COVID-19-Testing_10-24.xlsx
# Processing PA-DOC-COVID-19-Testing_10-25.xlsx
# Processing PA-DOC-COVID-19-Testing_10-26.xlsx
# Processing PA-DOC-COVID-19-Testing_10-31.xlsx
# Processing PA-DOC-COVID-19-Testing_10-5.xlsx
# Processing PA-DOC-COVID-19-Testing_10-6.xlsx
# Processing PA-DOC-COVID-19-Testing_10-7.xlsx
# Processing PA-DOC-COVID-19-Testing_10-8.xlsx
# Processing PA-DOC-COVID-19-Testing_10-9.xlsx
# Processing PA-DOC-COVID-19-Testing_11-10.xlsx
# Processing PA-DOC-COVID-19-Testing_11-13.xlsx
# Processing PA-DOC-COVID-19-Testing_11-15.xlsx
# Processing PA-DOC-COVID-19-Testing_11-16.xlsx
# Processing PA-DOC-COVID-19-Testing_11-17.xlsx
# Processing PA-DOC-COVID-19-Testing_11-18.xlsx
# Processing PA-DOC-COVID-19-Testing_11-19.xlsx
# Processing PA-DOC-COVID-19-Testing_11-20.xlsx
# Processing PA-DOC-COVID-19-Testing_11-21.xlsx
# Processing PA-DOC-COVID-19-Testing_11-23.xlsx
# Processing PA-DOC-COVID-19-Testing_11-5.xlsx
# Processing PA-DOC-COVID-19-Testing_11-9.xlsx
# Processing PA-DOC-COVID-19-Testing_7-17.xlsx
# Processing PA-DOC-COVID-19-Testing_7-18.xlsx
# Processing PA-DOC-COVID-19-Testing_7-19.xlsx
# Processing PA-DOC-COVID-19-Testing_7-23.xlsx
# Processing PA-DOC-COVID-19-Testing_7-24.xlsx
# Processing PA-DOC-COVID-19-Testing_7-30.xlsx
# Processing PA-DOC-COVID-19-Testing_8-12.xlsx
# Processing PA-DOC-COVID-19-Testing_8-13.xlsx
# Processing PA-DOC-COVID-19-Testing_8-27.xlsx
# Processing PA-DOC-COVID-19-Testing_8-4.xlsx
# Processing PA-DOC-COVID-19-Testing_8-9.xlsx
# Processing PA-DOC-COVID-19-Testing_9-25.xlsx

# %% [markdown]
# ### 3. Multiple tab spreadsheet for June 2-8

# %%
ss = pd.ExcelFile('../data/PA_DOC_testing_data/June2-8.xlsx')

# %%
ss.sheet_names
# Out:
# ['6-8', '6-5', '6-4', '6-2']

# %%
ss.parse('6-4')
# Out:
#       SCI/Institution  Staff Positive  Staff Negative  Staff Pending  \
# 0      Central Office             1.0               1            NaN
# 1              Albion             NaN               6            5.0
# 2     Benner Township             NaN              11            NaN
# 3   Cambridge Springs             NaN               7            1.0
# 4           Camp Hill             4.0               8           19.0
# 5             Chester            16.0              14           15.0
# 6       Coal Township             1.0              12            1.0
# 7              Dallas             2.0              11            3.0
# 8             Fayette             4.0              34            2.0
# 9              Forest             NaN               5            1.0
# 10         Frackville             NaN              19            7.0
# 11             Greene             1.0              26            2.0
# 12          Houtzdale             NaN               7            4.0
# 13         Huntingdon            54.0              81           13.0
# 14   Laurel Highlands             2.0               7            4.0
# 15            Mahanoy             NaN              12            3.0
# 16             Mercer             NaN               7            NaN
#
#     Staff Death With(+) Test  Staff Recovered  Inmate Positive  \
# 0                        NaN              NaN              NaN
# 1                        NaN              NaN              NaN
# 2                        NaN              NaN              1.0
# 3                        NaN              NaN              NaN
# 4                        NaN              3.0              1.0
# 5                        NaN             13.0              5.0
# 6                        NaN              1.0              NaN
# 7                        NaN              NaN              NaN
# 8                        NaN              2.0              1.0
# 9                        NaN              NaN              NaN
# 10                       NaN              NaN              NaN
# 11                       NaN              1.0              NaN
# 12                       NaN              NaN              NaN
# 13                       NaN             36.0            169.0
# 14                       NaN              NaN              NaN
# 15                       NaN              NaN              NaN
# 16                       NaN              NaN              NaN
#
#     Inmate Negative  Inmate Pending  Inmate Death With(+) Test  \
# 0               NaN             NaN                        NaN
# 1              52.0             1.0                        NaN
# 2              80.0             NaN                        NaN
# 3             111.0             NaN                        NaN
# 4             803.0            93.0                        NaN
# 5             217.0             NaN                        NaN
# 6              53.0             NaN                        NaN
# 7              71.0             NaN                        NaN
# 8              55.0             NaN                        NaN
# 9              27.0             NaN                        NaN
# 10             45.0             NaN                        NaN
# 11             35.0             NaN                        NaN
# 12             64.0             NaN                        NaN
# 13             74.0             3.0                        5.0
# 14             82.0             1.0                        NaN
# 15             44.0             NaN                        NaN
# 16             65.0             NaN                        NaN
#
#     Inmate Recovered  Transfer  Release  Hospital  Surveilance  Symptomatic  \
# 0                NaN       NaN      NaN       NaN          NaN          NaN
# 1                NaN       3.0     47.0       2.0          NaN          1.0
# 2                NaN       NaN     34.0       3.0         36.0          5.0
# 3                NaN       6.0     96.0       NaN          NaN          2.0
# 4                NaN     793.0     84.0       6.0          NaN          7.0
# 5                2.0       NaN     68.0       2.0        147.0          3.0
# 6                NaN       6.0     40.0       NaN          NaN          4.0
# 7                NaN       6.0     43.0       5.0          NaN          3.0
# 8                NaN       2.0     40.0       5.0          NaN          1.0
# 9                NaN       5.0     18.0       1.0          NaN          3.0
# 10               NaN       1.0     39.0       1.0          NaN          1.0
# 11               NaN       1.0     20.0       NaN          NaN          4.0
# 12               NaN       9.0     35.0       9.0          NaN          2.0
# 13             156.0       NaN      5.0      10.0         37.0        194.0
# 14               NaN       NaN     57.0       8.0          NaN         15.0
# 15               NaN       NaN     31.0       9.0          NaN          3.0
# 16               NaN       NaN      NaN       NaN          NaN          NaN
#
#     Miscellaneous
# 0             NaN
# 1             NaN
# 2             3.0
# 3             7.0
# 4             7.0
# 5             2.0
# 6             3.0
# 7            14.0
# 8             8.0
# 9             NaN
# 10            3.0
# 11           10.0
# 12            9.0
# 13            NaN
# 14            3.0
# 15            1.0
# 16            NaN

# %%
column_mapping3 = dict([(k.strip(),v) for k,v in column_mapping.items()])
column_mapping3
# Out:
# {'SCI/Institution': 'SCI',
#  'Staff Positive': 'staff_positive',
#  'Staff Negative': 'staff_negative',
#  'Staff Pending': 'staff_pending',
#  'Staff Death With(+) Test': 'staff_death',
#  'Staff Recovered': 'staff_recovered',
#  'Inmate Positive': 'incarcerated_person_positive',
#  'Inmate Negative': 'incarcerated_person_negative',
#  'Inmate Pending': 'incarcerated_person_pending',
#  'Inmate Death With(+) Test': 'incarcerated_person_death',
#  'Inmate Recovered': 'incarcerated_person_recovered',
#  'Transfer': 'test_transfer',
#  'Transfer (+)': 'test_transfer_positive',
#  'Release': 'test_release',
#  'Release (+)': 'test_release_positive',
#  'Hospital': 'test_hospital',
#  'Hospital (+)': 'test_hospital_positive',
#  'Surveilance': 'test_surveilance',
#  'Surveilance (+)': 'test_surveilance_positive',
#  'Symptomatic': 'test_symptomatic',
#  'Symptomatic (+)': 'test_symptomatic_positive',
#  'Miscellaneous': 'test_miscellaneous'}

# %%
data_type3=[]
for sname in ss.sheet_names:
    print('Processing',sname)
    month, day = sname.split('-')
    date = "2020-{:0>2}-{:0>2}".format(month,day)
    df=ss.parse(sname)
    df.rename(columns=column_mapping3, inplace=True)
    try:
        df2=df[column_mapping3.values()]
    except:
        df2=df
    df2['date']=date
    
    # drop Central Office
    df3 = df2[df2['SCI']!='Central Office']
    data_type3.append(df3)
# Out:
# Processing 6-8
# Processing 6-5
# Processing 6-4
# Processing 6-2

# %% [markdown]
# ### 4. Multiple tab spreadsheet for April 6 - June 1

# %%
ss2 = pd.ExcelFile('../data/PA_DOC_testing_data/April6-June1.xlsx')

# %%
ss2.sheet_names
# Out:
# ['6-1',
#  '5-29',
#  '5-28',
#  '5-27',
#  '5-26',
#  '5-22',
#  '5-21',
#  '5-20',
#  '5-19',
#  '5-15',
#  '5-14',
#  '5-13',
#  '5-12',
#  '5-11',
#  '5-8',
#  '5-7',
#  '5-6',
#  '5-5',
#  '4-10',
#  '4-9',
#  '4-8',
#  '4-7']

# %%
cnames=set()
for sn in ss2.sheet_names:
    cnames.update(list(ss2.parse(sn, skiprows=1).columns.values))

# %%
cnames
# Out:
# {'COVID TESTING',
#  'Death with (+) Test',
#  'Hospital',
#  'Miscellaneous',
#  'Negative',
#  'Negative.1',
#  'Other',
#  'Pending',
#  'Pending.1',
#  'Positive',
#  'Positive.1',
#  'Recovered',
#  'Release',
#  'Surveilance',
#  'Symptomatic',
#  'Total',
#  'Total Tests by site',
#  'Total.1',
#  'Transfer',
#  'Unnamed: 6'}

# %%
column_mapping4 = {
 'COVID TESTING': 'SCI',
 'Positive': 'staff_positive',
 'Negative': 'staff_negative',
 'Pending': 'staff_pending',
 'Positive.1': 'incarcerated_person_positive',
 'Negative.1': 'incarcerated_person_negative',
 'Pending.1': 'incarcerated_person_pending',
 'Death with (+) Test': 'incarcerated_person_death',
 'Recovered': 'incarcerated_person_recovered',

  # add test purpose columns
  # 'Transfer', 'Release', 'Hospital', 'Surveilance', 'Symptomatic', 'Miscellaneous'
'Transfer': 'test_transfer',
 'Release': 'test_release',
 'Hospital': 'test_hospital',
 'Surveilance': 'test_surveilance',
 'Symptomatic': 'test_symptomatic',
 'Miscellaneous': 'test_miscellaneous'
    
}

# %%
d=ss2.parse('5-21',skiprows=1).rename(columns=column_mapping4)

# %%
d.columns[d.columns.isin(column_mapping4.values())]
# Out:
# Index(['SCI', 'staff_positive', 'staff_negative', 'staff_pending',
#        'incarcerated_person_positive', 'incarcerated_person_negative',
#        'incarcerated_person_pending', 'incarcerated_person_death',
#        'incarcerated_person_recovered'],
#       dtype='object')

# %%
data_type4=[]
for sname in ss2.sheet_names:
    print('processing',sname)
    month, day = sname.split('-')
    date = "2020-{:0>2}-{:0>2}".format(month,day)
    df=ss2.parse(sname, skiprows=1)
    df.rename(columns=column_mapping4, inplace=True)
    cols_to_keep = df.columns[df.columns.isin(column_mapping4.values())]
    df2=df[cols_to_keep]
    df2['date']=date
    
    # drop Central Office
    df3 = df2[df2['SCI']!='Central Office']
    
    data_type4.append(df3)
# Out:
# processing 6-1
# processing 5-29
# processing 5-28
# processing 5-27
# processing 5-26
# processing 5-22
# processing 5-21
# processing 5-20
# processing 5-19
# processing 5-15
# processing 5-14
# processing 5-13
# processing 5-12
# processing 5-11
# processing 5-8
# processing 5-7
# processing 5-6
# processing 5-5
# processing 4-10
# processing 4-9
# processing 4-8
# processing 4-7
# /Users/mattodonnell/files/PA-SCI_COVID19/venv/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %% [markdown]
# ### Putting it all together

# %%
all_data=pd.concat(data_type1 + data_type2 + data_type3 + data_type4)

# %%
all_data.head()
# Out:
#                  SCI  staff_positive  staff_negative  staff_pending  \
# 1             Albion             NaN             7.0            4.0
# 2    Benner Township             NaN            11.0            1.0
# 3  Cambridge Springs             NaN             7.0            2.0
# 4          Camp Hill             4.0             8.0           20.0
# 5            Chester            16.0            14.0           17.0
#
#    staff_death  staff_recovered  incarcerated_person_positive  \
# 1          NaN              NaN                           NaN
# 2          NaN              NaN                           1.0
# 3          NaN              NaN                           NaN
# 4          NaN              3.0                           1.0
# 5          NaN             13.0                           5.0
#
#    incarcerated_person_negative  incarcerated_person_pending  \
# 1                          62.0                          NaN
# 2                          82.0                          NaN
# 3                         126.0                          NaN
# 4                         985.0                          2.0
# 5                         231.0                          NaN
#
#    incarcerated_person_death  ...  test_release  test_release_positive  \
# 1                        NaN  ...          48.0                    NaN
# 2                        NaN  ...          39.0                    1.0
# 3                        NaN  ...         116.0                    NaN
# 4                        NaN  ...         104.0                    NaN
# 5                        NaN  ...          72.0                    NaN
#
#    test_hospital  test_hospital_positive  test_surveilance  \
# 1            3.0                     NaN               NaN
# 2            3.0                     NaN              36.0
# 3            NaN                     NaN               NaN
# 4            6.0                     NaN               NaN
# 5            2.0                     NaN             147.0
#
#    test_surveilance_positive  test_symptomatic  test_symptomatic_positive  \
# 1                        NaN               1.0                        NaN
# 2                        NaN               5.0                        NaN
# 3                        NaN               2.0                        NaN
# 4                        NaN               7.0                        1.0
# 5                        3.0               3.0                        2.0
#
#    test_miscellaneous        date
# 1                 NaN  2020-06-10
# 2                 NaN  2020-06-10
# 3                 NaN  2020-06-10
# 4                 NaN  2020-06-10
# 5                 NaN  2020-06-10
#
# [5 rows x 23 columns]

# %%
all_data['date'].value_counts()
# Out:
# 2020-07-13    25
# 2020-10-06    25
# 2020-11-18    25
# 2020-06-18    25
# 2020-06-29    25
#               ..
# 2020-05-29    14
# 2020-05-28    14
# 2020-06-01    13
# 2020-06-05    12
# 2020-06-08    12
# Name: date, Length: 98, dtype: int64

# %%
all_data['SCI'].value_counts()
# Out:
# Chester              98
# Dallas               98
# Cambridge Springs    98
# Benner Township      98
# Houtzdale            98
# Forest               98
# Camp Hill            98
# Fayette              98
# Greene               98
# Frackville           98
# Coal Township        98
# Albion               98
# Huntingdon           96
# Laurel Highlands     95
# Mahanoy              93
# Mercer               93
# Phoenix              91
# Pine Grove           91
# Quehanna BC          91
# Muncy                91
# Retreat              76
# Rockview             74
# Waymart              72
# Somerset             72
# Smithfield           72
# Name: SCI, dtype: int64

# %%
all_data.index=pd.DatetimeIndex(all_data['date'])
all_data.sort_index(inplace=True)

# %%
all_data['date'].describe()
# Out:
# count           2283
# unique            98
# top       2020-07-13
# freq              25
# Name: date, dtype: object

# %%
all_data
# Out:
#                           SCI  staff_positive  staff_negative  staff_pending  \
# date
# 2020-04-07           Rockview             NaN             1.0            2.0
# 2020-04-07             Albion             NaN             5.0            2.0
# 2020-04-07    Benner Township             NaN             4.0            1.0
# 2020-04-07  Cambridge Springs             NaN             NaN            2.0
# 2020-04-07          Camp Hill             2.0             1.0            NaN
# ...                       ...             ...             ...            ...
# 2020-11-23           Rockview            53.0            41.0           20.0
# 2020-11-23         Smithfield            39.0           130.0           20.0
# 2020-11-23           Somerset            41.0            47.0           22.0
# 2020-11-23    Benner Township            46.0            56.0           65.0
# 2020-11-23         Huntingdon            82.0           177.0           29.0
#
#             staff_death  staff_recovered  incarcerated_person_positive  \
# date
# 2020-04-07          NaN              NaN                           NaN
# 2020-04-07          NaN              NaN                           NaN
# 2020-04-07          NaN              NaN                           NaN
# 2020-04-07          NaN              NaN                           NaN
# 2020-04-07          NaN              NaN                           NaN
# ...                 ...              ...                           ...
# 2020-11-23          NaN             12.0                          46.0
# 2020-11-23          NaN             18.0                          38.0
# 2020-11-23          NaN             10.0                         210.0
# 2020-11-23          NaN             35.0                          24.0
# 2020-11-23          NaN             70.0                         201.0
#
#             incarcerated_person_negative  incarcerated_person_pending  \
# date
# 2020-04-07                           NaN                          NaN
# 2020-04-07                           NaN                          NaN
# 2020-04-07                           2.0                          NaN
# 2020-04-07                           2.0                          NaN
# 2020-04-07                           NaN                          1.0
# ...                                  ...                          ...
# 2020-11-23                         763.0                         93.0
# 2020-11-23                         508.0                        153.0
# 2020-11-23                         640.0                        475.0
# 2020-11-23                         389.0                         79.0
# 2020-11-23                         555.0                         69.0
#
#             incarcerated_person_death  ...  test_release  \
# date                                   ...
# 2020-04-07                        NaN  ...           NaN
# 2020-04-07                        NaN  ...           NaN
# 2020-04-07                        NaN  ...           NaN
# 2020-04-07                        NaN  ...           NaN
# 2020-04-07                        NaN  ...           NaN
# ...                               ...  ...           ...
# 2020-11-23                        1.0  ...         266.0
# 2020-11-23                        NaN  ...         245.0
# 2020-11-23                        NaN  ...         320.0
# 2020-11-23                        1.0  ...         256.0
# 2020-11-23                        5.0  ...         161.0
#
#             test_release_positive  test_hospital  test_hospital_positive  \
# date
# 2020-04-07                    NaN            NaN                     NaN
# 2020-04-07                    NaN            NaN                     NaN
# 2020-04-07                    NaN            NaN                     NaN
# 2020-04-07                    NaN            NaN                     NaN
# 2020-04-07                    NaN            NaN                     NaN
# ...                           ...            ...                     ...
# 2020-11-23                    1.0           32.0                     4.0
# 2020-11-23                    5.0           36.0                     5.0
# 2020-11-23                    4.0          121.0                     4.0
# 2020-11-23                    1.0           17.0                     1.0
# 2020-11-23                    6.0           23.0                    11.0
#
#             test_surveilance  test_surveilance_positive  test_symptomatic  \
# date
# 2020-04-07               NaN                        NaN               NaN
# 2020-04-07               NaN                        NaN               NaN
# 2020-04-07               NaN                        NaN               NaN
# 2020-04-07               NaN                        NaN               NaN
# 2020-04-07               NaN                        NaN               NaN
# ...                      ...                        ...               ...
# 2020-11-23              25.0                       13.0              36.0
# 2020-11-23              96.0                       16.0              14.0
# 2020-11-23             466.0                      179.0              32.0
# 2020-11-23              61.0                        9.0              20.0
# 2020-11-23             257.0                       51.0             195.0
#
#             test_symptomatic_positive  test_miscellaneous        date
# date
# 2020-04-07                        NaN                 NaN  2020-04-07
# 2020-04-07                        NaN                 NaN  2020-04-07
# 2020-04-07                        NaN                 NaN  2020-04-07
# 2020-04-07                        NaN                 NaN  2020-04-07
# 2020-04-07                        NaN                 NaN  2020-04-07
# ...                               ...                 ...         ...
# 2020-11-23                       23.0                 NaN  2020-11-23
# 2020-11-23                       10.0                 NaN  2020-11-23
# 2020-11-23                       19.0                 NaN  2020-11-23
# 2020-11-23                       13.0                 NaN  2020-11-23
# 2020-11-23                      128.0                 NaN  2020-11-23
#
# [2283 rows x 23 columns]

# %%
doc2_df = all_data.copy()
doc2_df=doc2_df.drop(columns='date').reset_index()

exclude_cols = ['SCI', 'date', 'date.1']

cols_to_use = [c for c in doc2_df.columns if c not in exclude_cols]

for col in cols_to_use:
    print('Calculating delta for', col)
    doc2_df[f'{col}_new'] = doc2_df.groupby('SCI')[col].diff()
    
doc2_df=doc2_df.set_index(doc2_df['date'])
# Out:
# Calculating delta for staff_positive
# Calculating delta for staff_negative
# Calculating delta for staff_pending
# Calculating delta for staff_death
# Calculating delta for staff_recovered
# Calculating delta for incarcerated_person_positive
# Calculating delta for incarcerated_person_negative
# Calculating delta for incarcerated_person_pending
# Calculating delta for incarcerated_person_death
# Calculating delta for incarcerated_person_recovered
# Calculating delta for test_transfer
# Calculating delta for test_transfer_positive
# Calculating delta for test_release
# Calculating delta for test_release_positive
# Calculating delta for test_hospital
# Calculating delta for test_hospital_positive
# Calculating delta for test_surveilance
# Calculating delta for test_surveilance_positive
# Calculating delta for test_symptomatic
# Calculating delta for test_symptomatic_positive
# Calculating delta for test_miscellaneous

# %%
doc2_df.to_csv('../data/latest_data/PA_DOC_testing_data.csv')

# %%
doc2_df
# Out:
#                  date                SCI  staff_positive  staff_negative  \
# date
# 2020-04-07 2020-04-07           Rockview             NaN             1.0
# 2020-04-07 2020-04-07             Albion             NaN             5.0
# 2020-04-07 2020-04-07    Benner Township             NaN             4.0
# 2020-04-07 2020-04-07  Cambridge Springs             NaN             NaN
# 2020-04-07 2020-04-07          Camp Hill             2.0             1.0
# ...               ...                ...             ...             ...
# 2020-11-23 2020-11-23           Rockview            53.0            41.0
# 2020-11-23 2020-11-23         Smithfield            39.0           130.0
# 2020-11-23 2020-11-23           Somerset            41.0            47.0
# 2020-11-23 2020-11-23    Benner Township            46.0            56.0
# 2020-11-23 2020-11-23         Huntingdon            82.0           177.0
#
#             staff_pending  staff_death  staff_recovered  \
# date
# 2020-04-07            2.0          NaN              NaN
# 2020-04-07            2.0          NaN              NaN
# 2020-04-07            1.0          NaN              NaN
# 2020-04-07            2.0          NaN              NaN
# 2020-04-07            NaN          NaN              NaN
# ...                   ...          ...              ...
# 2020-11-23           20.0          NaN             12.0
# 2020-11-23           20.0          NaN             18.0
# 2020-11-23           22.0          NaN             10.0
# 2020-11-23           65.0          NaN             35.0
# 2020-11-23           29.0          NaN             70.0
#
#             incarcerated_person_positive  incarcerated_person_negative  \
# date
# 2020-04-07                           NaN                           NaN
# 2020-04-07                           NaN                           NaN
# 2020-04-07                           NaN                           2.0
# 2020-04-07                           NaN                           2.0
# 2020-04-07                           NaN                           NaN
# ...                                  ...                           ...
# 2020-11-23                          46.0                         763.0
# 2020-11-23                          38.0                         508.0
# 2020-11-23                         210.0                         640.0
# 2020-11-23                          24.0                         389.0
# 2020-11-23                         201.0                         555.0
#
#             incarcerated_person_pending  ...  test_transfer_positive_new  \
# date                                     ...
# 2020-04-07                          NaN  ...                         NaN
# 2020-04-07                          NaN  ...                         NaN
# 2020-04-07                          NaN  ...                         NaN
# 2020-04-07                          NaN  ...                         NaN
# 2020-04-07                          1.0  ...                         NaN
# ...                                 ...  ...                         ...
# 2020-11-23                         93.0  ...                         0.0
# 2020-11-23                        153.0  ...                         0.0
# 2020-11-23                        475.0  ...                         0.0
# 2020-11-23                         79.0  ...                         0.0
# 2020-11-23                         69.0  ...                         0.0
#
#             test_release_new  test_release_positive_new  test_hospital_new  \
# date
# 2020-04-07               NaN                        NaN                NaN
# 2020-04-07               NaN                        NaN                NaN
# 2020-04-07               NaN                        NaN                NaN
# 2020-04-07               NaN                        NaN                NaN
# 2020-04-07               NaN                        NaN                NaN
# ...                      ...                        ...                ...
# 2020-11-23               0.0                        0.0                0.0
# 2020-11-23               0.0                        0.0                0.0
# 2020-11-23               0.0                        0.0                0.0
# 2020-11-23               0.0                        0.0                0.0
# 2020-11-23               0.0                        0.0                0.0
#
#             test_hospital_positive_new  test_surveilance_new  \
# date
# 2020-04-07                         NaN                   NaN
# 2020-04-07                         NaN                   NaN
# 2020-04-07                         NaN                   NaN
# 2020-04-07                         NaN                   NaN
# 2020-04-07                         NaN                   NaN
# ...                                ...                   ...
# 2020-11-23                         0.0                   2.0
# 2020-11-23                         0.0                   0.0
# 2020-11-23                         0.0                   1.0
# 2020-11-23                         0.0                   0.0
# 2020-11-23                         0.0                   0.0
#
#             test_surveilance_positive_new  test_symptomatic_new  \
# date
# 2020-04-07                            NaN                   NaN
# 2020-04-07                            NaN                   NaN
# 2020-04-07                            NaN                   NaN
# 2020-04-07                            NaN                   NaN
# 2020-04-07                            NaN                   NaN
# ...                                   ...                   ...
# 2020-11-23                            2.0                   1.0
# 2020-11-23                            0.0                   0.0
# 2020-11-23                          123.0                   0.0
# 2020-11-23                            0.0                   0.0
# 2020-11-23                            0.0                   0.0
#
#             test_symptomatic_positive_new  test_miscellaneous_new
# date
# 2020-04-07                            NaN                     NaN
# 2020-04-07                            NaN                     NaN
# 2020-04-07                            NaN                     NaN
# 2020-04-07                            NaN                     NaN
# 2020-04-07                            NaN                     NaN
# ...                                   ...                     ...
# 2020-11-23                            1.0                     NaN
# 2020-11-23                            0.0                     NaN
# 2020-11-23                            2.0                     NaN
# 2020-11-23                            0.0                     NaN
# 2020-11-23                            0.0                     NaN
#
# [2283 rows x 44 columns]
